# %%
#import statements
import pandas as pd
#glob is useful for working with filepaths
import glob
import math
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import re

#setting up spotify credentials
def set_spotify():
    client_id = 'd0b2731526744c759fcf012a56ec5bd5'
    client_secret = '6e593cabd0e043da9041c5ef5825dec7'

    #Sets up authentication to use the Spotify API
    client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
    #Creates a Spotipy session using the credentials
    sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
    return sp

sp = set_spotify()

# %%
# The playlist_id is taken from the playlist URL: https://open.spotify.com/playlist/4YFfrhWUFFH5BdPmoBm2kx
# The playlist is named "Machine Learning Capstone Playlist".
playlist_id = '4YFfrhWUFFH5BdPmoBm2kx'

#Pull tracks out of playlist for parsing later
result = sp.user_playlist_tracks("addie.jasica", playlist_id, offset=150)


track_list = []
#append the amount of track IDs needed and place them in a list along with the track name as a double check
for i in range(len(result['items'])):
    track_list.append(result['items'][i]['track']['id'] + ": " + result['items'][i]['track']['name'])

for item in track_list:
    print(item)
# Out:
# 5XMkENs3GfeRza8MfVAhjK: Finesse
# 0N3W5peJUQtI4eyR6GJT5O: King Kunta
# 6I9VzXrHxO9rA9A5euc8Ak: Toxic
# 7gevvAspxft2qQmcvJjNBH: A Good Night
# 74wySERHHxB8Ul9A0CNBla: Lay All Your Love On Me - From 'Mamma Mia!' Original Motion Picture Soundtrack
# 4VfvjHFWjbjjg94LGVFipA: You'll Find A Way (Switch and Sinden Remix)
# 0GLUBbX4daHJkT3RQHEOia: Upgrade U (feat. Jay-Z)
# 41L3O37CECZt3N7ziG2z7l: Yummy
# 3ibAzRj9JnowdoLkyllk3n: Holiday
# 4QNpBfC0zvjKqPJcyqBy9W: Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)
# 4umIPjkehX1r7uhmGvXiSV: Intentions (feat. Quavo)
# 1ZPlNanZsJSPK5h9YZZFbZ: Like a Virgin
# 1jye0ZfUs4eb8iw41UcKSH: Love Me For The Weekend (with Ashe)
# 5leOhwmC0JYwAPxo6zGUHP: Seventeen
# 1TfqLAPs4K3s2rJMoCokcS: Sweet Dreams (Are Made of This) - Remastered
# 76N7FdzCI9OsiUnzJVLY2m: Rumour Has It
# 0HPD5WQqrq7wPWR7P7Dw1i: TiK ToK
# 2k6oLQC0nAw99WL1euDWdG: PAPI
# 7FuRjlwyTY9uTAUgGpZtJU: Jump Jive An' Wail
# 36phXHOKx8rO7CMp2vNX4x: Love Myself
# 7GK2KVYH8FrTC9zehmjVMd: Ring My Bell
# 6W8VktzOUZNlOdTMaeLuxv: If I Can't Have You
# 5cXtT63OTadsjqfRkm5Dwd: Deepthroat
# 0ew27xRdxSexrWbODuLfeE: I'm Coming Out
# 20ORwCJusz4KS2PbTPVNKo: Leavin'
# 150zGw0P2EJccYJKnFIler: Drop The Game
# 0M6ceBATSgswJqB3M8JywI: Crush
# 4w3tQBXhn5345eUXDGBWZG: 9 to 5
# 3RauEVgRgj1IuWdJ9fDs70: The Man
# 2aIdVb8v9KTpEZnftkz2mD: Buy U a Drank (Shawty Snappin') (feat. Yung Joc)
# 6lUY6MoqGgPnA27PHYxem5: Bulletproof
# 1M4qEo4HE3PRaCOM7EXNJq: Adore You
# 0sYnQF94tdLTOpyoaJNn7F: Rabbit Hole
# 7gkWXbAxIYuvtOpcN3p9GJ: God is a woman
# 27356GVuMPFWiJSZCragoM: make up
# 4aKIs5t9TqP59btlCGPrgw: Maneater
# 6IwKcFdiRQZOWeYNhUiWIv: No One
# 3qEu5RQnsEcSBX8SkiwJEG: 1, 2 Step (feat. Missy Elliott) - Main
# 4nVyHATevhl5RC6Qmoko5H: I Like It
# 0wkGHuJlJNe8dvUfw9i6fK: S&M
# 2pbWkjtGtjkzBdZ95GFINm: Car Wash
# 4BBt0kc625eUAdG2XpWPHm: Called Out In The Dark
# 2Iib2MV3ECFJAourgP9dlY: La Isla Bonita
# 6X1D6qbVmK48uoOD9nIvVV: Grease - From “Grease”
# 6MBEjJlXQYXr8dfxDvZuoA: Do It To It
# 6ntkwU1MhehTKgx4BWxX3f: Hoedown Throwdown

# %%
artist= 'Jonas Brothers'
track= 'S.O.S.'

track_id = sp.search(q='artist:' + artist + ' track:' + track, type='track')

# %%
track_id
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=artist%3AJonas+Brothers+track%3AS.O.S.&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#        'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#        'id': '7gOdHgIoIKoe4i9Tta6qdD',
#        'name': 'Jonas Brothers',
#        'type': 'artist',
#        'uri': 'spotify:artist:7gOdHgIoIKoe4i9Tta6qdD'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4myOCm6FzD9TMdK7Q0Nzx0'},
#      'href': 'https://api.spotify.com/v1/albums/4myOCm6FzD9TMdK7Q0Nzx0',
#      'id': '4myOCm6FzD9TMdK7Q0Nzx0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c4b78c2342107d01853df43f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c4b78c2342107d01853df43f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c4b78c2342107d01853df43f',
#        'width': 64}],
#      'name': 'Jonas Brothers',
#      'release_date': '2007-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:4myOCm6FzD9TMdK7Q0Nzx0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#       'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#       'id': '7gOdHgIoIKoe4i9Tta6qdD',
#       'name': 'Jonas Brothers',
#       'type': 'artist',
#       'uri': 'spotify:artist:7gOdHgIoIKoe4i9Tta6qdD'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 153346,
#     'explicit': False,
#     'external_ids': {'isrc': 'USHR10723189'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6sDP4912wjwB7BJhbSnjS1'},
#     'href': 'https://api.spotify.com/v1/tracks/6sDP4912wjwB7BJhbSnjS1',
#     'id': '6sDP4912wjwB7BJhbSnjS1',
#     'is_local': False,
#     'name': 'S.O.S.',
#     'popularity': 65,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6sDP4912wjwB7BJhbSnjS1'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#        'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#        'id': '7gOdHgIoIKoe4i9Tta6qdD',
#        'name': 'Jonas Brothers',
#        'type': 'artist',
#        'uri': 'spotify:artist:7gOdHgIoIKoe4i9Tta6qdD'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6X2HirVqcGXjLBShA8GUW2'},
#      'href': 'https://api.spotify.com/v1/albums/6X2HirVqcGXjLBShA8GUW2',
#      'id': '6X2HirVqcGXjLBShA8GUW2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f61f60835543b02511652241',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f61f60835543b02511652241',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f61f60835543b02511652241',
#        'width': 64}],
#      'name': 'Music From Chasing Happiness',
#      'release_date': '2019-05-09',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:6X2HirVqcGXjLBShA8GUW2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#       'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#       'id': '7gOdHgIoIKoe4i9Tta6qdD',
#       'name': 'Jonas Brothers',
#       'type': 'artist',
#       'uri': 'spotify:artist:7gOdHgIoIKoe4i9Tta6qdD'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 153346,
#     'explicit': False,
#     'external_ids': {'isrc': 'USHR10723189'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3GETuR15a1z76xzYYiScGc'},
#     'href': 'https://api.spotify.com/v1/tracks/3GETuR15a1z76xzYYiScGc',
#     'id': '3GETuR15a1z76xzYYiScGc',
#     'is_local': False,
#     'name': 'S.O.S.',
#     'popularity': 42,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3GETuR15a1z76xzYYiScGc'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#        'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#        'id': '7gOdHgIoIKoe4i9Tta6qdD',
#        'name': 'Jonas Brothers',
#        'type': 'artist',
#        'uri': 'spotify:artist:7gOdHgIoIKoe4i9Tta6qdD'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7qUIb0W4UremjN76P5SVaY'},
#      'href': 'https://api.spotify.com/v1/albums/7qUIb0W4UremjN76P5SVaY',
#      'id': '7qUIb0W4UremjN76P5SVaY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731121a9feb0bbcf4b9517e11f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021121a9feb0bbcf4b9517e11f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511121a9feb0bbcf4b9517e11f',
#        'width': 64}],
#      'name': 'Music From Chasing Happiness',
#      'release_date': '2019-12-20',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:7qUIb0W4UremjN76P5SVaY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#       'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#       'id': '7gOdHgIoIKoe4i9Tta6qdD',
#       'name': 'Jonas Brothers',
#       'type': 'artist',
#       'uri': 'spotify:artist:7gOdHgIoIKoe4i9Tta6qdD'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 153346,
#     'explicit': False,
#     'external_ids': {'isrc': 'USHR10723189'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4BfmwIHuo6LITtvxFHsNnw'},
#     'href': 'https://api.spotify.com/v1/tracks/4BfmwIHuo6LITtvxFHsNnw',
#     'id': '4BfmwIHuo6LITtvxFHsNnw',
#     'is_local': False,
#     'name': 'S.O.S.',
#     'popularity': 42,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4BfmwIHuo6LITtvxFHsNnw'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#        'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#        'id': '7gOdHgIoIKoe4i9Tta6qdD',
#        'name': 'Jonas Brothers',
#        'type': 'artist',
#        'uri': 'spotify:artist:7gOdHgIoIKoe4i9Tta6qdD'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4myOCm6FzD9TMdK7Q0Nzx0'},
#      'href': 'https://api.spotify.com/v1/albums/4myOCm6FzD9TMdK7Q0Nzx0',
#      'id': '4myOCm6FzD9TMdK7Q0Nzx0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c4b78c2342107d01853df43f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c4b78c2342107d01853df43f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c4b78c2342107d01853df43f',
#        'width': 64}],
#      'name': 'Jonas Brothers',
#      'release_date': '2007-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:4myOCm6FzD9TMdK7Q0Nzx0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#       'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#       'id': '7gOdHgIoIKoe4i9Tta6qdD',
#       'name': 'Jonas Brothers',
#       'type': 'artist',
#       'uri': 'spotify:artist:7gOdHgIoIKoe4i9Tta6qdD'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 175120,
#     'explicit': False,
#     'external_ids': {'isrc': 'USHR10823876'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/384vV5HSEqO9c0ZlRgu6i9'},
#     'href': 'https://api.spotify.com/v1/tracks/384vV5HSEqO9c0ZlRgu6i9',
#     'id': '384vV5HSEqO9c0ZlRgu6i9',
#     'is_local': False,
#     'name': 'S.O.S. - Live',
#     'popularity': 35,
#     'preview_url': None,
#     'track_number': 14,
#     'type': 'track',
#     'uri': 'spotify:track:384vV5HSEqO9c0ZlRgu6i9'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#        'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#        'id': '7gOdHgIoIKoe4i9Tta6qdD',
#        'name': 'Jonas Brothers',
#        'type': 'artist',
#        'uri': 'spotify:artist:7gOdHgIoIKoe4i9Tta6qdD'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2qLi0Q8fs8YLSDH5WbE8Vc'},
#      'href': 'https://api.spotify.com/v1/albums/2qLi0Q8fs8YLSDH5WbE8Vc',
#      'id': '2qLi0Q8fs8YLSDH5WbE8Vc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735e0f4b509e71ef57a82ccc3e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025e0f4b509e71ef57a82ccc3e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515e0f4b509e71ef57a82ccc3e',
#        'width': 64}],
#      'name': 'Music from the 3D Concert Experience',
#      'release_date': '2009-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:2qLi0Q8fs8YLSDH5WbE8Vc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#       'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#       'id': '7gOdHgIoIKoe4i9Tta6qdD',
#       'name': 'Jonas Brothers',
#       'type': 'artist',
#       'uri': 'spotify:artist:7gOdHgIoIKoe4i9Tta6qdD'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 150186,
#     'explicit': False,
#     'external_ids': {'isrc': 'USHR10924305'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3GC2EVxUmyP8jlULHWMAba'},
#     'href': 'https://api.spotify.com/v1/tracks/3GC2EVxUmyP8jlULHWMAba',
#     'id': '3GC2EVxUmyP8jlULHWMAba',
#     'is_local': False,
#     'name': 'S.O.S. - The 3D Concert Experience',
#     'popularity': 25,
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:3GC2EVxUmyP8jlULHWMAba'}],
#   'limit': 10,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 5}}

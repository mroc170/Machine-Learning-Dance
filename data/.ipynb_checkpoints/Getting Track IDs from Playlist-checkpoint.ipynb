# %%
#import statements
import pandas as pd
#glob is useful for working with filepaths
import glob
import math
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import re

#setting up spotify credentials
def set_spotify():
    client_id = 'd0b2731526744c759fcf012a56ec5bd5'
    client_secret = '6e593cabd0e043da9041c5ef5825dec7'

    #Sets up authentication to use the Spotify API
    client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
    #Creates a Spotipy session using the credentials
    sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
    return sp

sp = set_spotify()

# %%
# The playlist_id is taken from the playlist URL: https://open.spotify.com/playlist/4YFfrhWUFFH5BdPmoBm2kx
# The playlist is named "Machine Learning Capstone Playlist".
playlist_id = '4YFfrhWUFFH5BdPmoBm2kx'

#Pull tracks out of playlist for parsing later
result = sp.user_playlist_tracks("addie.jasica", playlist_id)


track_list = []
#append the amount of track IDs needed and place them in a list along with the track name as a double check
for i in range(len(result['items'])):
    track_list.append(result['items'][i]['track']['id'] + ": " + result['items'][i]['track']['name'])

for item in track_list:
    print(item)
# Out:
# 6WSBZroxQaO3FYEpT2ACFH: Baptized In Fire
# 5FxVTEpoBress37MmlMhbZ: By Design
# 2Fxmhks0bxGSBdJ92vM42m: bad guy
# 0Ryd8975WihbObpp5cPW1t: boyfriend (with Social House)
# 1RKZvaLj3UPhGjZkaIrFm7: Que Calor (feat. J Balvin & El Alfa)
# 1OUPXna2MCgAt3VNmXJBtg: Bola Rebola
# 09CtPGIpYB4BrO8qb1RGsF: Sorry
# 4B0JvthVoAAuygILe3n4Bs: What Do You Mean?
# 2tUBqZG2AbRi7Q0BIrVrEj: I Wanna Dance with Somebody (Who Loves Me)
# 6LsAAHotRLMOHfCsSfYCsz: If I Can't Have You
# 3BtuIIrQlkujKPuWF2B85z: Too Good
# 5Ssv6DaKrW0HczVqx6zXdl: Diva
# 2wAJTrFhCnQyNSD3oUgTZO: Work Out
# 3e9HZxeyfWwjeyPAMmWSSQ: thank u, next
# 3YZE5qDV7u1ZD1gZc47ZeR: Underneath the Tree
# 5N4erncE7kuUccm7zEmwzk: Electricity (with Dua Lipa)
# 5qGwqO0lkbBXw4xNfzT7SF: Spice Up Your Life
# 7wfQfnNFGWLD0BzcDngCRg: Money
# 6oG7bmUn7ws0qYEJ0eEbeG: Touch
# 7gvd8xj4QgPqbQSsn5pV7d: Sorry Not Sorry
# 6zsk6uF3MxfIeHPlubKBvR: Get Ur Freak On
# 44CZRkOxv7UItaAUmh8PgN: Doses & Mimosas
# 58q2HKrzhC3ozto2nDdN4z: I Like It
# 7hySbX6I73xmWGN9HERH3u: Sweat Dreams
# 6nBQFAIVFmAx2oZ8p6lUg6: Tempo (feat. Missy Elliott)
# 7D8aQaRzoi9Qzz5yerVK5b: Throw A Fit
# 0rIAC4PXANcKmitJfoqmVm: Motivation
# 31CsLSgn0HdZEVC8Bnnmvr: Bootylicious
# 39hnH8WdPmNT3Q3yzwC9Rg: Why You Always Hatin?
# 32OlwWuMpZ6b0aN2RZOeMS: Uptown Funk
# 5fyIGoaaKelzdyW8ELhYJZ: Feeling Myself
# 6mz1fBdKATx6qP4oP1I65G: Pony
# 7uKcScNXuO3MWw6LowBjW1: One, Two Step (feat. Missy Elliott)
# 3DmIFdqlcNZlZKlj2flToA: Radar - Bloodshy & Avant Remix - 2009 Remaster
# 794F99D5BQHS5ZGRXAs7I5: Anaconda
# 2LKlHBPHxLG5ArAXfF148n: Lemon - Edit
# 2hloaUoRonYssMuqLCBLTX: bloodline
# 5w9c2J52mkdntKOmRLeM2m: Con Calma
# 57mKcbEq7nMqtJ4gqJvWcp: Talk That Talk
# 3Yt9lRtS5V4nbJnwcgFgvC: You Da One
# 4cTm3Ev9bUvy4ChJjB1nhl: Juicy
# 76VtA90NKurNqaQpV126Ue: Pour It Up
# 1AWQoqb9bSvzTjaLralEkT: Rock Your Body
# 6WrI0LAC5M1Rw2MnX2ZvEg: Don't Start Now
# 5IVuqXILoxVWvWEPm82Jxr: Crazy In Love (feat. Jay-Z)
# 1pKeFVVUOPjFsOABub0OaV: Side To Side
# 5MMLS3xm12D7N26xlfFApr: Runaway Baby
# 1gZ7i4qxXkHZb1r6eioaAP: Don't Cha
# 1Je1IMUlBXcx1Fz0WE7oPT: Wannabe
# 21RzyxY3EFaxVy6K4RqaU9: Body
# 3D4uUFRoYDFHbkQlTKL2Om: Give A Little
# 1D066zixBwqFYqBhKgdPzp: Fergalicious
# 63OshgWbxCtI1WHb5C0Txd: Work - R3hab Remix
# 5RxpYHVbGJPOvSEATQyg9P: Lucy
# 6URlKrAIlJJwHnHxxXWywt: Short Kings Anthem
# 05mAIVLkIWc2d1UBYZBCp8: 1999
# 6b2RcmUt1g9N9mQ3CbjX2Y: How Do You Sleep?
# 7vgv8KZBSo0TPzyIWG9yzV: Salt
# 2G7V7zsVDxg1yRsu7Ew9RJ: In My Feelings
# 3HVWdVOQ0ZA45FuZGSfvns: I Don't Care (with Justin Bieber)
# 2AobDJxjDp5TbxGdR3JGen: Let the Groove Get In
# 0O45fw2L5vsWpdsOdXwNAR: SexyBack (feat. Timbaland)
# 0YGQ3hZcRLC5YX7o0hdmHg: Naughty Girl
# 2ekn2ttSfGqwhhate0LSR0: New Rules
# 3HWzoMvoF3TQfYg4UPszDq: Truth Hurts
# 0KoiMHhqKLoL4xM54rcWYY: Taki Taki (feat. Selena Gomez, Ozuna & Cardi B)
# 6oJ6le65B3SEqPwMRNXWjY: Higher Love
# 6iOvnACn4ChlAw4lWUU4dd: Go To Town
# 4pmc2AxSEq6g7hPVlJCPyP: Jumpin', Jumpin'
# 3dFwpxh2yH7C7p9BGEKLVB: Goodies (feat. Petey Pablo)
# 0rwtN4afj6ikDB3nkcuZ2X: Dose
# 1DqdF42leyFIzqNDv9CjId: Dynamite
# 3TGRqZ0a2l1LRblBkJoaDx: Call Me Maybe
# 5QspkeTnBCstPaJ15sbMcW: Falling
# 1fN6ieuPCAQRfqG3nxds7u: I Remember
# 0k664IuFwVP557Gnx7RhIl: Juice
# 2Mpj1Ul5OFPyyP4wB62Rvi: Survivor
# 7qiZfU4dY1lWllzX7mPBI3: Shape of You
# 4pnIUqhf1AQMFrJPd4BbrT: Ballin Flossin
# 1tNJrcVe6gwLEiZCtprs1u: 3 Nights
# 4sYCWzivvHyGGAbz8JTbbQ: Lost In Your Light (feat. Miguel)
# 2gTYVoQCUh0QNUaFix01ld: Chun-Li
# 1zi7xx7UVEFkmKfv06H8x0: One Dance
# 5I7sGubUsKo4mVJpBoSVUr: Like a Girl
# 3jVtllWS5CFFWLQng8sKsr: 2 On (feat. ScHoolboy Q)
# 5gW5dSy3vXJxgzma4rQuzH: Make Me Feel
# 4HfLQJtVT1KiX1eVedDyTm: Alaska
# 1snNAXmmPXCn0dkF9DaPWw: You & Me - Flume Remix
# 4yietxYiyMVs8THopnDwXn: This Love
# 0AKejOKlGdiB53QpwAeenO: Don't Wanna Know
# 4zP7ADsgJgHGY6VzxbNp1z: Year 3000
# 5jrr4qdmd6jmstVgHxCXMO: Personal
# 7Cuk8jsPPoNYQWXK9XRFvG: September
# 5EYi2rH4LYs6M21ZLOyQTx: Loving Is Easy
# 1B0BQaSRHxhI0AUlItY3LK: MALAMENTE - Cap.1: Augurio
# 4TsmezEQVSZNNPv5RJ65Ov: Pon de Replay
# 6IAVxNFi1W88UhDeyvOsdo: Fat Bottomed Girls - 2011 Remaster
# 0JiY190vktuhSGN6aqJdrt: So What
# 5Y2pr8wjzjO2te4MnxTUa7: Calabria 2008
